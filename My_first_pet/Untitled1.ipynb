# %%
import cianparser

uu_parser = cianparser.CianParser(location="Улан-Удэ")
data = uu_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":2})

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\User\Desktop\My_first_pet\cian_flat_sale_1_2_ulan-ude_04_May_2024_15_05_54_239676.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=5026&deal_type=sale&offer_type=flat&room1=1&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 50 %. Average price: 21 353 424 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 100 %. Average price: 25 026 303 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 56.
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('cian_flat_sale_1_2_ulan-ude_04_May_2024_15_02_11_615549.csv')

# %%
df
# Out:
#    author;author_type;url;location;deal_type;accommodation_type;floor;floors_count;rooms_count;total_meters;price;district;street;house_number;underground;residential_complex
# 0   Альбина Галсанимаева;realtor;https://ulan-ude....
# 1   Неал-Недвижимость;real_estate_agent;https://ul...
# 2   Неал-Недвижимость;real_estate_agent;https://ul...
# 3   Альбина Галсанимаева;realtor;https://ulan-ude....
# 4   Альбина Галсанимаева;realtor;https://ulan-ude....
# 5   Неал-Недвижимость;real_estate_agent;https://ul...
# 6   Альбина Галсанимаева;realtor;https://ulan-ude....
# 7   ID 115933019;homeowner;https://ulan-ude.cian.r...
# 8   Альбина Галсанимаева;realtor;https://ulan-ude....
# 9   ID 101382178;homeowner;https://ulan-ude.cian.r...
# 10  Неал-Недвижимость;real_estate_agent;https://ul...
# 11  Неал-Недвижимость;real_estate_agent;https://ul...
# 12  Неал-Недвижимость;real_estate_agent;https://ul...
# 13  Неал-Недвижимость;real_estate_agent;https://ul...
# ...
